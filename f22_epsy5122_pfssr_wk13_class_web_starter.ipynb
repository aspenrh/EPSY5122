# %% [markdown]
# ##### EPSY 5122: Programming Fundamentals for Social Science Researchers
# ## Fall 2022 Week 13
# ### Web Scraping with Python

# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
# this just loads all fxns and attaches their names to our enviro
# in other words, no need to use the package name

# %%
# some functions adapted from RealPython demo:
# https://realpython.com/python-web-scraping-practical-introduction/

def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try: # make an attempt to do this, but if there's an ERROR, jump to the "except"
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp): # calls function defined below
                return resp.content
            else:
                return None
    except RequestException as e: # only runs if error occurs above
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 # remember that 200 means all OK!
            and content_type is not None # makes sure there's *something* in content
            and content_type.find('html') > -1)


def log_error(e): # just in case error above, prints it
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
raw = simple_get("https://research.umn.edu/inquiry/posts")

# %%
raw
# Out:
# b'<!DOCTYPE html>\n<!--[if IEMobile 7]><html class="iem7"  lang="en" dir="ltr"><![endif]-->\n<!--[if lte IE 6]><html class="lt-ie9 lt-ie8 lt-ie7"  lang="en" dir="ltr"><![endif]-->\n<!--[if (IE 7)&(!IEMobile)]><html class="lt-ie9 lt-ie8"  lang="en" dir="ltr"><![endif]-->\n<!--[if IE 8]><html class="lt-ie9"  lang="en" dir="ltr"><![endif]-->\n<!--[if (gte IE 9)|(gt IEMobile 7)]><!--><html  lang="en" dir="ltr" prefix="fb: http://ogp.me/ns/fb# og: http://ogp.me/ns#"><!--<![endif]-->\n\n<head>\n  <meta charset="utf-8" />\n<link rel="shortcut icon" href="https://research.umn.edu/sites/research.umn.edu/themes/umn_ovpr_subtheme/favicon.ico" type="image/vnd.microsoft.icon" />\n<meta name="generator" content="Drupal 7 (https://www.drupal.org)" />\n<link rel="canonical" href="https://research.umn.edu/inquiry/posts" />\n<link rel="shortlink" href="https://research.umn.edu/inquiry/posts" />\n<meta property="og:site_name" content="Office of the Vice President for Research" />\n<meta property="og:type" content="article" />\n<meta property="og:url" content="https://research.umn.edu/inquiry/posts" />\n<meta property="og:title" content="Blog Post Listing" />\n<meta name="twitter:card" content="summary" />\n<meta name="twitter:url" content="https://research.umn.edu/inquiry/posts" />\n<meta name="twitter:title" content="Blog Post Listing" />\n<meta name="dcterms.title" content="Blog Post Listing" />\n<meta name="dcterms.type" content="Text" />\n<meta name="dcterms.format" content="text/html" />\n<meta name="dcterms.identifier" content="https://research.umn.edu/inquiry/posts" />\n  <title>Blog Post Listing | Office of the Vice President for Research</title>\n\n      <meta name="MobileOptimized" content="width">\n    <meta name="HandheldFriendly" content="true">\n    <meta name="viewport" content="width=device-width">\n    <meta charset="UTF-8">\n  <meta http-equiv="cleartype" content="on">\n    <link rel="apple-touch-icon" href="/sites/research.umn.edu/themes/umn_ovpr_subtheme/img/ovpr-touchicon.png">\n\n  <link type="text/css" rel="stylesheet" href="https://research.umn.edu/sites/research.umn.edu/files/css/css_lQaZfjVpwP_oGNqdtWCSpJT1EMqXdMiU84ekLLxQnc4.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://research.umn.edu/sites/research.umn.edu/files/css/css_YYks_YhEXLcEg7i7V4cokAsS7LFsu2nE193s3ua1AnE.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://research.umn.edu/sites/research.umn.edu/files/css/css_XPQEbHaqg2qBoox8keY2rseWARU_jE_72lyvQcQi-qo.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://research.umn.edu/sites/research.umn.edu/files/css/css_vv0P0E5JpTV9zL1_6mTg9P2bbE2S_Q_aaA-yX_Q-zks.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://research.umn.edu/sites/research.umn.edu/files/css/css_v4xm0f0PdnVGjboEyNn97wGDYezSovBMgVcBfy2AgEg.css" media="all" />\n  <script src="https://research.umn.edu/sites/research.umn.edu/files/js/js_s7yA-hwRxnKty__ED6DuqmTMKG39xvpRyrtyCrbWH4M.js"></script>\n<script src="https://research.umn.edu/sites/research.umn.edu/files/js/js_sEAj06aHui8uDGeNEKizuwZKbro5N0e1ttyTEF88JSU.js"></script>\n<script src="https://research.umn.edu/sites/research.umn.edu/files/js/js_vq4IsdR1gDYGozBadJ9GyJNy_EEIwuaaSL-AgBFQ0x0.js"></script>\n<script>var switchTo5x = true;var useFastShare = true;</script>\n<script src="https://ws.sharethis.com/button/buttons.js"></script>\n<script>if (typeof stLight !== \'undefined\') { stLight.options({"publisher":"59641652d892a00011311149","version":"5x","lang":"en"}); }</script>\n<script src="https://research.umn.edu/sites/research.umn.edu/files/js/js_xI_XRBJXC9e5IFQC5_BEW-HpViMPNCdnT682VdwwabI.js"></script>\n<script>(function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","//www.google-analytics.com/analytics.js", ...

# %%
type(raw)
# Out:
# bytes

# %%
proc = BeautifulSoup(raw, "html.parser")
proc
# Out:
# <!DOCTYPE html>
#
# <!--[if IEMobile 7]><html class="iem7"  lang="en" dir="ltr"><![endif]-->
# <!--[if lte IE 6]><html class="lt-ie9 lt-ie8 lt-ie7"  lang="en" dir="ltr"><![endif]-->
# <!--[if (IE 7)&(!IEMobile)]><html class="lt-ie9 lt-ie8"  lang="en" dir="ltr"><![endif]-->
# <!--[if IE 8]><html class="lt-ie9"  lang="en" dir="ltr"><![endif]-->
# <!--[if (gte IE 9)|(gt IEMobile 7)]><!--><html dir="ltr" lang="en" prefix="fb: http://ogp.me/ns/fb# og: http://ogp.me/ns#"><!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <link href="https://research.umn.edu/sites/research.umn.edu/themes/umn_ovpr_subtheme/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <meta content="Drupal 7 (https://www.drupal.org)" name="generator"/>
# <link href="https://research.umn.edu/inquiry/posts" rel="canonical"/>
# <link href="https://research.umn.edu/inquiry/posts" rel="shortlink"/>
# <meta content="Office of the Vice President for Research" property="og:site_name"/>
# <meta content="article" property="og:type"/>
# <meta content="https://research.umn.edu/inquiry/posts" property="og:url"/>
# <meta content="Blog Post Listing" property="og:title"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="https://research.umn.edu/inquiry/posts" name="twitter:url"/>
# <meta content="Blog Post Listing" name="twitter:title"/>
# <meta content="Blog Post Listing" name="dcterms.title"/>
# <meta content="Text" name="dcterms.type"/>
# <meta content="text/html" name="dcterms.format"/>
# <meta content="https://research.umn.edu/inquiry/posts" name="dcterms.identifier"/>
# <title>Blog Post Listing | Office of the Vice President for Research</title>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width" name="viewport"/>
# <meta charset="utf-8"/>
# <meta content="on" http-equiv="cleartype"/>
# <link href="/sites/research.umn.edu/themes/umn_ovpr_subtheme/img/ovpr-touchicon.png" rel="apple-touch-icon"/>
# <link href="https://research.umn.edu/sites/research.umn.edu/files/css/css_lQaZfjVpwP_oGNqdtWCSpJT1EMqXdMiU84ekLLxQnc4.css" media="all" rel="stylesheet" type="text/css">
# <link href="https://research.umn.edu/sites/research.umn.edu/files/css/css_YYks_YhEXLcEg7i7V4cokAsS7LFsu2nE193s3ua1AnE.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://research.umn.edu/sites/research.umn.edu/files/css/css_XPQEbHaqg2qBoox8keY2rseWARU_jE_72lyvQcQi-qo.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://research.umn.edu/sites/research.umn.edu/files/css/css_vv0P0E5JpTV9zL1_6mTg9P2bbE2S_Q_aaA-yX_Q-zks.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://research.umn.edu/sites/research.umn.edu/files/css/css_v4xm0f0PdnVGjboEyNn97wGDYezSovBMgVcBfy2AgEg.css" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://research.umn.edu/sites/research.umn.edu/files/js/js_s7yA-hwRxnKty__ED6DuqmTMKG39xvpRyrtyCrbWH4M.js"></script>
# <script src="https://research.umn.edu/sites/research.umn.edu/files/js/js_sEAj06aHui8uDGeNEKizuwZKbro5N0e1ttyTEF88JSU.js"></script>
# <script src="https://research.umn.edu/sites/research.umn.edu/files/js/js_vq4IsdR1gDYGozBadJ9GyJNy_EEIwuaaSL-AgBFQ0x0.js"></script>
# <script>var switchTo5x = true;var useFastShare = true;</script>
# <script src="https://ws.sharethis.com/button/buttons.js"></script>
# <script>if (typeof stLight !== 'undefined') { stLight.options({"publisher":"59641652d892a00011311149","version":"5x","lang":"en"}); }</script>
# <script src="https://research.umn.edu/sites/research.umn.edu/files/js/js_xI_XRBJXC9e5IFQC5_BEW-HpViMPNCdnT682VdwwabI.js"></script>
# <script>(function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","//www.google-analytics.com/analytics.js","ga");ga("create", "UA-4025728-3", {"cookieDomain":"auto"});ga("set", "anonymizeIp", true);ga("send", "pageview");</script>
# <script src="https://research.umn.edu/sites/research.umn.edu/files/js/js_v3CCtA90seCuKHd390iKMDQ_iTFd1duL6PugLsymvOQ.js"></script>
# <script src="https://research.umn.edu/sites/research.umn.edu/files/js/js_4ZW78DFCc-bc3wUUYYQ2aDEn7sH1_g8JWxbNh_Rf5yM.js"></script>
# <script>jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","setHasJsCookie":0,"ajaxPageState":{"theme":"umn_ovpr_subtheme","theme_token":"H1-bsTZhcv3OXg-yyQyU-ViH0d7a7fpObzjDjKFiFds","js":{"profiles\/umncore\/modules\/panopoly\/panopoly_widgets\/panopoly-widgets.js":1,"profiles\/umncore\/modules\/panopoly\/panopoly_widgets\/panopoly-widgets-spotlight.js":1,"profiles\/umncore\/modules\/contrib\/jquery_update\/replace\/jquery\/1.8\/jquery.min.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"profiles\/umncore\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.core.min.js":1,"profiles\/umncore\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.widget.min.js":1,"profiles\/umncore\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.effect.min.js":1,"profiles\/umncore\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.accordion.min.js":1,"sites\/research.umn.edu\/modules\/contrib\/jquery_ui_filter\/jquery_ui_filter.js":1,"profiles\/umncore\/modules\/contrib\/admin_menu\/admin_devel\/admin_devel.js":1,"profiles\/umncore\/modules\/contrib\/back_to_top\/js\/back_to_top.js":1,"profiles\/umncore\/modules\/contrib\/caption_filter\/js\/caption-filter.js":1,"0":1,"https:\/\/ws.sharethis.com\/button\/buttons.js":1,"1":1,"profiles\/umncore\/modules\/contrib\/responsive_menus\/styles\/responsive_menus_simple\/js\/responsive_menus_simple.js":1,"profiles\/umncore\/modules\/contrib\/google_analytics\/googleanalytics.js":1,"2":1,"profiles\/umncore\/modules\/palantir_custom\/umn_search\/js\/cse_script.js":1,"profiles\/umncore\/modules\/palantir_custom\/umn_search\/js\/umn_mobile_search.js":1,"profiles\/umncore\/themes\/umn\/umn_base_theme\/js\/umn_accordin_custom.js":1,"profiles\/umncore\/themes\/umn\/umn_base_theme\/js\/custom.js":1,"profiles\/umncore\/themes\/umn\/umn_base_theme\/js\/aria-accordion.js":1,"sites\/research.umn.edu\/themes\/umn_ovpr_subtheme\/js\/foundation.min.js":1,"sites\/research.umn.edu\/themes\/umn_ovpr_subtheme\/js\/jquery.tablesorter.min.js":1,"sites\/research.umn.edu\/themes\/umn_ovpr_subtheme\/js\/app.js":1,"sites\/research.umn.edu\/themes\/umn_ovpr_subtheme\/js\/script.js":1,"sites\/research.umn.edu\/themes\/umn_ovpr_subtheme\/js\/umnhf-2015.js":1,"sites\/research.umn.edu\/themes\/umn_ovpr_subtheme\/js\/html5shiv-printshiv.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"misc\/ui\/jquery.ui.theme.css":1,"misc\/ui\/jquery.ui.accordion.css":1,"modules\/field\/theme\/field.css":1,"profiles\/umncore\/modules\/contrib\/google_appliance\/theme\/google_appliance.css":1,"modules\/node\/node.css":1,"profiles\/umncore\/modules\/panopoly\/panopoly_core\/css\/panopoly-dropbutton.css":1,"profiles\/umncore\/modules\/panopoly\/panopoly_widgets\/panopoly-widgets.css":1,"profiles\/umncore\/modules\/panopoly\/panopoly_widgets\/panopoly-widgets-spotlight.css":1,"profiles\/umncore\/modules\/contrib\/radix_layouts\/radix_layouts.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"profiles\/umncore\/modules\/contrib\/views\/css\/views.css":1,"profiles\/umncore\/modules\/contrib\/back_to_top\/css\/back_to_top.css":1,"profiles\/umncore\/modules\/contrib\/caption_filter\/caption-filter.css":1,"profiles\/umncore\/modules\/contrib\/media\/modules\/media_wysiwyg\/css\/media_wysiwyg.base.css":1,"profiles\/umncore\/modules\/contrib\/ctools\/css\/ctools.css":1,"profiles\/umncore\/modules\/contrib\/panels\/css\/panels.css":1,"profiles\/umncore\/modules\/contrib\/date\/date_api\/date.css":1,"profiles\/umncore\/modules\/contrib\/addressfield\/addressfield.css":1,"profiles\/umncore\/modules\/contrib\/responsive_menus\/styles\/responsive_menus_simple\/css\/responsive_menus_simple.css":1,"profiles\/umncore\/modules\/palantir_custom\/umn_search\/css\/u ...
# <!--[if lt IE 9]>
#     <script src="/profiles/umncore/themes/zen/js/html5-respond.js"></script>
#     <![endif]-->
# <!-- add mailchimp pop up
#   <script type="text/javascript" src="//downloads.mailchimp.com/js/signup-forms/popup/unique-methods/embed.js" data-dojo-config="usePlainJson: true, isDebug: false"></script>
#   <script type="text/javascript">
#     window.showInquirySubscribe = false; // only show it if this has been made true;
#     jQuery(document).ready(
#      function() {if (window.showInquirySubscribe) {
#         window.dojoRequire(["mojo/signup-forms/Loader"], function(L) { L.start({"baseUrl":"mc.us1.list-manage.com","uuid":"072feca402aaa9d7a64ab3972","lid":"367a10b4dc","uniqueMethods":true}) });
#       }}
#     );
#   </script> -->
# </link></head>
# <body class="html not-front not-logged-in no-sidebars page-inquiry page-inquiry-posts region-content section-inquiry page-views">
# <div class="admin-page-tools">
# </div>
# <a class="sr-only sr-only-focusable element-invisible element-focusable" href="#skip-to-main-content">Skip to Content</a>
# <header class="site-header no-main-nav">
# <!-- BEGIN HEADER -->
# <header class="umnhf" id="umnhf-h" role="banner">
# <!-- Skip Links: Give your nav and content elements the appropriate ID attributes -->
# <div class="printer"><div class="left"></div><div class="right">University of Minnesota<!-- br />http://twin-cities.umn.edu/<br />612-625-5000 --></div></div>
# <div class="umnhf" id="umnhf-h-mast">
# <a class="umnhf" href="http://twin-cities.umn.edu/" id="umnhf-h-logo"><span>Go to the U of M home page</span></a>
# <ul class="umnhf" id="umnhf-h-ql">
# <li><a href="http://onestop.umn.edu/">One Stop</a></li>
# <li class="umnhf"><a href="https://www.myu.umn.edu/">MyU <span></span></a></li>
# </ul>
# <!-- Button below is for dropdown toggle, only visible on mobile screens. If using
#                         a non-dropdown version you can delete this tag -->
# <button class="umnhf" id="umnhf-m-search">Search</button>
# <form action="//search.umn.edu/tc/" class="umnhf" id="umnhf-h-search" method="get" role="search" title="Search Websites and People">
# <label class="umnhf" for="umnhf-h-st">Search</label>
# <input class="umnhf" id="umnhf-h-st" name="q" type="text"/>
# <label class="umnhf" for="umnhf-h-sb">Submit search query</label>
# <input class="umnhf" id="umnhf-h-sb" type="submit" value=""/>
# </form>
# </div>
# </header>
# <!-- END HEADER -->
# <div class="top-bar secondary-nav">
# <div class="row column">
# <div class="region region-ovpr-back-to-ovpr">
# <h3 class="header-return-link"><a href="/"><svg height="11px" version="1.1" viewbox="0 0 12 11" width="12px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g fill="none" fill-rule="evenodd" id="Final-Designs" stroke="none" stroke-width="1">
# <g fill="#FFFFFF" id="OVPR-SubSite_v4" transform="translate(-135.000000, -65.000000)">
# <g id="OVPR-Header" transform="translate(0.000000, 49.000000)">
# <g id="ic_home_black_24px" transform="translate(135.000000, 16.000000)">
# <g id="Group">
# <polygon id="Shape" points="4.8 10.7666667 4.8 6.96666667 7.2 6.96666667 7.2 10.7666667 10.2 10.7666667 10.2 5.7 12 5.7 6 0 0 5.7 1.8 5.7 1.8 10.7666667"></polygon>
# </g>
# </g>
# </g>
# </g>
# </g>
# </svg>Office of the Vice President for Research</a></h3>
# </div>
# <div class="top-bar-left">
# <div class="region region-blog-header">
# <div class="block block-imageblock first last odd" id="block-imageblock-1">
# <div class="block-image">
# <a class="imageblock-link" href="/inquiry" target="_self"><img alt="Inquiry Blog Header" class="imageblock-image" src="https://research.umn.edu/sites/research.umn.edu/files/styles/large/public/imageblock/inquiry-png.png?itok=X2uCHs5o" title="Inquiry Blog Header"/></a> </div>
# </div>
# </div>
# </div>
# <div class="top-bar-right">
# <div class="hide-for-small show-for-large">
# <div class="region region-ovpr-util-menu">
# <div class="block block-menu-block first last odd" id="block-menu-block-11" role="navigation">
# <div class="menu-block-wrapper menu-block-11 menu-name-menu-inquiry-blog-menu parent-mlid-0 menu-level-2">
# <ul class="menu"><li class="menu__item is-leaf first last leaf menu-mlid-24876"><a class="menu__link" href="/inquiry/about-us">About Us</a></li>
# </ul></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="content-wrapper">
# <section class="row column">
# <nav aria-label="You are here:" role="navigation">
# <h2 class="element-invisible">You are here</h2><div class="breadcrumb"><span class="inline odd first"><a href="/">Home</a></span> <span class="delimiter">»</span> <span class="inline even"><a href="/inquiry">Inquiry</a></span> <span class="delimiter">»</span> <span class="inline odd last">Blog Post Listing</span></div> </nav>
# </section> <div class="main">
# <section class="page-content">
# <div class="row">
# <div class="small-12 column medium-10 large-9 small-centered">
# <a class="sr-only sr-only-focusable" id="skip-to-main-content" name="skip-to-main-content" tabindex="-1"></a>
# <div class="view view-ovpr-blog-post-listing view-id-ovpr_blog_post_listing view-display-id-page_1 view-dom-id-488237d98a29fee6b0110f7daaa04646">
# <div class="view-filters">
# <form accept-charset="UTF-8" action="/inquiry/posts" id="views-exposed-form-ovpr-blog-post-listing-page-1" method="get"><div>
# <div class="callout filter">
# <div class="views-exposed-form">
# <div class="views-exposed-widgets clearfix">
# <div class="views-exposed-widget views-widget-filter-field_blog_post_categories_tid" id="edit-category-wrapper">
# <label for="edit-category">
#                 Categories              </label>
# <div class="views-widget">
# <div class="form-item form-type-select form-item-category">
# <select class="form-select" id="edit-category" name="category"><option selected="selected" value="All">- Any -</option><option value="41">Infrastructure &amp; Capabilities</option><option value="31">Research &amp; Discovery</option><option value="36">Vision &amp; Impact</option><option value="26">Business &amp; Technology</option></select>
# </div>
# </div>
# </div>
# <div class="views-exposed-widget views-widget-filter-field_blog_post_contributor_target_id" id="edit-contributor-wrapper">
# <label for="edit-contributor">
#                 Contributor              </label>
# <div class="views-widget">
# <div class="form-item form-type-select form-item-contributor">
# <select class="form-select" id="edit-contributor" name="contributor"><option selected="selected" value="All">- Any -</option><option value="1126">Contributing Writer</option><option value="7331">Dan Gilchrist</option><option value="1111">Deane Morrison</option><option value="191">Erin Dennis</option><option value="186">Kevin Coss</option><option value="7046">Kirsten Gray</option><option value="1121">Meher Khan</option><option value="8951">Vaughn Schmid</option></select>
# </div>
# </div>
# </div>
# <div class="views-exposed-widget views-submit-button">
# <input class="form-submit" id="edit-submit-ovpr-blog-post-listing" type="submit" value="Filter"> </input></div>
# </div>
# </div>
# </div></div></form> </div>
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first">
# <div class="post blog-post-teaser">
# <div class="row">
# <!-- Image -->
# <div class="post-media medium-4 column">
# <a href="/inquiry/post/sunsetting-inquiry-introducing-umn-research">
# <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/sunsetting-inquiry-introducing-umn-research"><img alt="Sun setting over a prarie scene" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/inquiry-sunset-istock-1401293030.png?itok=HtY2zB6H" width="600"/></a></div></div></div> </a>
# </div>
# <div class="post-text medium-8 column">
# <!-- Headline -->
# <h2 class="post-headline"><a href="/inquiry/post/sunsetting-inquiry-introducing-umn-research">Sunsetting Inquiry, Introducing UMN Research</a></h2>
# <!-- Blog Date -->
# <div class="events-meta">
# <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">August 1, 2022</span></div></div></div> </div>
# <!-- Contributor -->
# <!-- Teaser -->
# <div class="post-teaser">
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p>After eight productive years, we are phasing out the <em>Inquiry</em> blog and launching a new monthly newsletter focused on news, information, and resources for our systemwide research community.</p>
# </div></div></div> </div>
# <!-- Button -->
# <a class="button secondary button-arrow button-wide" href="/inquiry/post/sunsetting-inquiry-introducing-umn-research">Continue Reading</a>
# <!-- Category -->
# <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
# <div class="field-label">Categories: </div>
# <div class="field-items">
# <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="views-row views-row-2 views-row-even">
# <div class="post blog-post-teaser">
# <div class="row">
# <!-- Image -->
# <div class="post-media medium-4 column">
# <a href="/inquiry/post/community-engaged-research-spurs-change-policy-domestic-violence-colombia">
# <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/community-engaged-research-spurs-change-policy-domestic-violence-colombia"><img alt="Dr. Friedemann-Sanchez and Dr. Grieve sitting at a table together." height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-friedemann-sanchez_and_grieve.png?itok=3AYbi5_X" width="600"/></a></div></div></div> </a>
# </div>
# <div class="post-text medium-8 column">
# <!-- Headline -->
# <h2 class="post-headline"><a href="/inquiry/post/community-engaged-research-spurs-change-policy-domestic-violence-colombia">Community-Engaged Research Spurs Change in Policy on Domestic Violence in Colombia</a></h2>
# <!-- Blog Date -->
# <div class="events-meta">
# <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">December 21, 2021</span></div></div></div> </div>
# <!-- Contributor -->
# <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
# <!-- Teaser -->
# <div class="post-teaser">
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p>In 2018, two University of Minnesota researchers traveled to a United Nations council meeting to advocate for changes to address an epidemic of violence against women in Colombia.</p>
# </div></div></div> </div>
# <!-- Button -->
# <a class="button secondary button-arrow button-wide" href="/inquiry/post/community-engaged-research-spurs-change-policy-domestic-violence-colombia">Continue Reading</a>
# <!-- Category -->
# <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
# <div class="field-label">Categories: </div>
# <div class="field-items">
# <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="views-row views-row-3 views-row-odd">
# <div class="post blog-post-teaser">
# <div class="row">
# <!-- Image -->
# <div class="post-media medium-4 column">
# <a href="/inquiry/post/getting-root-health-disparities-kidney-disease">
# <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/getting-root-health-disparities-kidney-disease"><img alt="Senior man speaks with a health care provider while looking at a digital display" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-medication-management.png?itok=Aw7-AduA" width="600"/></a></div></div></div> </a>
# </div>
# <div class="post-text medium-8 column">
# <!-- Headline -->
# <h2 class="post-headline"><a href="/inquiry/post/getting-root-health-disparities-kidney-disease">Getting to the Root of Health Disparities in Kidney Disease</a></h2>
# <!-- Blog Date -->
# <div class="events-meta">
# <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">October 28, 2021</span></div></div></div> </div>
# <!-- Contributor -->
# <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
# <!-- Teaser -->
# <div class="post-teaser">
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p><span>Researchers aim to help train pharmacists and educate patients with the goal of improving medication outcomes for groups with higher rates of kidney failure.</span></p>
# </div></div></div> </div>
# <!-- Button -->
# <a class="button secondary button-arrow button-wide" href="/inquiry/post/getting-root-health-disparities-kidney-disease">Continue Reading</a>
# <!-- Category -->
# <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
# <div class="field-label">Categories: </div>
# <div class="field-items">
# <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="views-row views-row-4 views-row-even">
# <div class="post blog-post-teaser">
# <div class="row">
# <!-- Image -->
# <div class="post-media medium-4 column">
# <a href="/inquiry/post/startup-scales-eco-friendly-ingredients-cleaning-personal-care">
# <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/startup-scales-eco-friendly-ingredients-cleaning-personal-care"><img alt="Sironix banner in a laboratory space" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-sironix-1.png?itok=chRAGh0C" width="600"/></a></div></div></div> </a>
# </div>
# <div class="post-text medium-8 column">
# <!-- Headline -->
# <h2 class="post-headline"><a href="/inquiry/post/startup-scales-eco-friendly-ingredients-cleaning-personal-care">Startup Scales Up Eco-Friendly Ingredients for Cleaning, Personal Care</a></h2>
# <!-- Blog Date -->
# <div class="events-meta">
# <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">October 27, 2021</span></div></div></div> </div>
# <!-- Contributor -->
# <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
# <!-- Teaser -->
# <div class="post-teaser">
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p><span>Sironix Renewables uses a patented method to make nontoxic, sustainably-sourced surfactants that replace their counterparts made from petroleum.</span></p>
# </div></div></div> </div>
# <!-- Button -->
# <a class="button secondary button-arrow button-wide" href="/inquiry/post/startup-scales-eco-friendly-ingredients-cleaning-personal-care">Continue Reading</a>
# <!-- Category -->
# <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
# <div class="field-label">Categories: </div>
# <div class="field-items">
# <a href="/inquiry/posts?category=26">Business &amp; Technology</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="views-row views-row-5 views-row-odd">
# <div class="post blog-post-teaser">
# <div class="row">
# <!-- Image -->
# <div class="post-media medium-4 column">
# <a href="/inquiry/post/contemporary-history-brings-insight-asylum-cases">
# <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/contemporary-history-brings-insight-asylum-cases"><img alt="Border crossing checkpoint from Mexico to US" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-border-entry.png?itok=N1KE7y_3" width="600"/></a></div></div></div> </a>
# </div>
# <div class="post-text medium-8 column">
# <!-- Headline -->
# <h2 class="post-headline"><a href="/inquiry/post/contemporary-history-brings-insight-asylum-cases">Contemporary History Brings Insight to Asylum Cases</a></h2>
# <!-- Blog Date -->
# <div class="events-meta">
# <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">October 27, 2021</span></div></div></div> </div>
# <!-- Contributor -->
# <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
# <!-- Teaser -->
# <div class="post-teaser">
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p><span>As an expert witness on federal immigration court cases, Patrick McNamara provides insight into violence directly and indirectly related to drug cartels.</span></p>
# </div></div></div> </div>
# <!-- Button -->
# <a class="button secondary button-arrow button-wide" href="/inquiry/post/contemporary-history-brings-insight-asylum-cases">Continue Reading</a>
# <!-- Category -->
# <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
# <div class="field-label">Categories: </div>
# <div class="field-items">
# <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="views-row views-row-6 views-row-even">
# <div class="post blog-post-teaser">
# <div class="row">
# <!-- Image -->
# <div class="post-media medium-4 column">
# <a href="/inquiry/post/mapping-out-life-ideas-champion-humanities">
# <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/mapping-out-life-ideas-champion-humanities"><img alt="Edward Said portrait" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-edward-said.png?itok=5tCNc2mm" width="600"/></a></div></div></div> </a>
# </div>
# <div class="post-text medium-8 column">
# <!-- Headline -->
# <h2 class="post-headline"><a href="/inquiry/post/mapping-out-life-ideas-champion-humanities">Mapping Out the Life &amp; Ideas of a Champion of the Humanities</a></h2>
# <!-- Blog Date -->
# <div class="events-meta">
# <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">October 27, 2021</span></div></div></div> </div>
# <!-- Contributor -->
# <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
# <!-- Teaser -->
# <div class="post-teaser">
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p><span>The first comprehensive biography of Edward Said explores how the public figure's intellectual breadth and influence developed over the years.</span></p>
# </div></div></div> </div>
# <!-- Button -->
# <a class="button secondary button-arrow button-wide" href="/inquiry/post/mapping-out-life-ideas-champion-humanities">Continue Reading</a>
# <!-- Category -->
# <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
# <div class="field-label">Categories: </div>
# <div class="field-items">
# <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="views-row views-row-7 views-row-odd">
# <div class="post blog-post-teaser">
# <div class="row">
# <!-- Image -->
# <div class="post-media medium-4 column">
# <a href="/inquiry/post/saving-oaks-remote-sensing-could-detect-invasive-fungus-earlier">
# <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/saving-oaks-remote-sensing-could-detect-invasive-fungus-earlier"><img alt="Oak tree in a sunny field" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-oak-tree.png?itok=sdNoiGMN" width="600"/></a></div></div></div> </a>
# </div>
# <div class="post-text medium-8 column">
# <!-- Headline -->
# <h2 class="post-headline"><a href="/inquiry/post/saving-oaks-remote-sensing-could-detect-invasive-fungus-earlier">Saving Oaks: Remote Sensing Could Detect Invasive Fungus Earlier</a></h2>
# <!-- Blog Date -->
# <div class="events-meta">
# <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">September 30, 2021</span></div></div></div> </div>
# <!-- Contributor -->
# <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
# <!-- Teaser -->
# <div class="post-teaser">
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p><span>Hyperspectral imaging may provide a quicker and more accurate way to detect trees infected with oak wilt and inform efforts to stanch the disease's spread.</span></p>
# </div></div></div> </div>
# <!-- Button -->
# <a class="button secondary button-arrow button-wide" href="/inquiry/post/saving-oaks-remote-sensing-could-detect-invasive-fungus-earlier">Continue Reading</a>
# <!-- Category -->
# <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
# <div class="field-label">Categories: </div>
# <div class="field-items">
# <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="views-row views-row-8 views-row-even">
# <div class="post blog-post-teaser">
# <div class="row">
# <!-- Image -->
# <div class="post-media medium-4 column">
# <a href="/inquiry/post/globalization-bane-traditional-languages-and-skills">
# <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/globalization-bane-traditional-languages-and-skills"><img alt="Adults sitting wearing traditional costumes and children wearing school uniforms" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-papuanewguinea.png?itok=caZXQ6u4" width="600"/></a></div></div></div> </a>
# </div>
# <div class="post-text medium-8 column">
# <!-- Headline -->
# <h2 class="post-headline"><a href="/inquiry/post/globalization-bane-traditional-languages-and-skills">Globalization, the Bane of Traditional Languages and Skills</a></h2>
# <!-- Blog Date -->
# <div class="events-meta">
# <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">September 30, 2021</span></div></div></div> </div>
# <!-- Contributor -->
# <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Deane Morrison</p></div></div></div>
# <!-- Teaser -->
# <div class="post-teaser">
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p class="Body"><span>A sizable gap in indigenous language fluency and traditional practices has opened up between teenage students and their parents in Papua New Guinea.</span></p>
# </div></div></div> </div>
# <!-- Button -->
# <a class="button secondary button-arrow button-wide" href="/inquiry/post/globalization-bane-traditional-languages-and-skills">Continue Reading</a>
# <!-- Category -->
# <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
# <div class="field-label">Categories: </div>
# <div class="field-items">
# <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="views-row views-row-9 views-row-odd">
# <div class="post blog-post-teaser">
# <div class="row">
# <!-- Image -->
# <div class="post-media medium-4 column">
# <a href="/inquiry/post/research-purpose-new-model-combines-philosophy-and-science">
# <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/research-purpose-new-model-combines-philosophy-and-science"><img alt="Multitude of blue butterflies with a single orange butterfly atop them" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-butterflies.png?itok=h5gmishv" width="600"/></a></div></div></div> </a>
# </div>
# <div class="post-text medium-8 column">
# <!-- Headline -->
# <h2 class="post-headline"><a href="/inquiry/post/research-purpose-new-model-combines-philosophy-and-science">Research on Purpose: New Model Combines Philosophy and Science</a></h2>
# <!-- Blog Date -->
# <div class="events-meta">
# <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">September 27, 2021</span></div></div></div> </div>
# <!-- Contributor -->
# <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
# <!-- Teaser -->
# <div class="post-teaser">
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p><span>Through nearly $15 million in Templeton Foundation funding, a new international cohort program led by a UMN philosophy researcher aims to explore purposive-looking behavior in living systems.</span></p>
# </div></div></div> </div>
# <!-- Button -->
# <a class="button secondary button-arrow button-wide" href="/inquiry/post/research-purpose-new-model-combines-philosophy-and-science">Continue Reading</a>
# <!-- Category -->
# <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
# <div class="field-label">Categories: </div>
# <div class="field-items">
# <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="views-row views-row-10 views-row-even views-row-last">
# <div class="post blog-post-teaser">
# <div class="row">
# <!-- Image -->
# <div class="post-media medium-4 column">
# <a href="/inquiry/post/new-award-program-celebrates-impact-research-innovation">
# <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/new-award-program-celebrates-impact-research-innovation"><img alt="Graphic reading Innovation Impact Case Award" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/innovation_main_inquiry.png?itok=76Vh7BRc" width="600"/></a></div></div></div> </a>
# </div>
# <div class="post-text medium-8 column">
# <!-- Headline -->
# <h2 class="post-headline"><a href="/inquiry/post/new-award-program-celebrates-impact-research-innovation">New Award Program Celebrates Impact of Research &amp; Innovation</a></h2>
# <!-- Blog Date -->
# <div class="events-meta">
# <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">September 24, 2021</span></div></div></div> </div>
# <!-- Contributor -->
# <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
# <!-- Teaser -->
# <div class="post-teaser">
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p><span>The new Innovation Impact Case Award celebrates work that solves challenges and benefits individuals, organizations, and communities.</span></p>
# </div></div></div> </div>
# <!-- Button -->
# <a class="button secondary button-arrow button-wide" href="/inquiry/post/new-award-program-celebrates-impact-research-innovation">Continue Reading</a>
# <!-- Category -->
# <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
# <div class="field-label">Categories: </div>
# <div class="field-items">
# <a href="/inquiry/posts?category=36">Vision &amp; Impact</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <h2 class="element-invisible">Pages</h2><div class="item-list"><ul class="pager"><li class="pager-current first">1</li>
# <li class="pager-item"><a href="/inquiry/posts?page=1" title="Go to page 2">2</a></li>
# <li class="pager-item"><a href="/inquiry/posts?page=2" title="Go to page 3">3</a></li>
# <li class="pager-item"><a href="/inquiry/posts?page=3" title="Go to page 4">4</a></li>
# <li class="pager-item"><a href="/inquiry/posts?page=4" title="Go to page 5">5</a></li>
# <li class="pager-ellipsis">…</li>
# <li class="pager-next"><a href="/inquiry/posts?page=1">Next</a></li>
# <li class="pager-last last"><a href="/inquiry/posts?page=38">Last</a></li>
# </ul></div>
# </div>
# </div>
# </div>
# </section>
# </div>
# <section class="subscribe">
# <div class="row">
# <div class="column small-12 medium-10 medium-centered large-centered">
# <div class="callout large">
# <div class="region region-ovpr-newsletter">
# <div class="block block-block first last odd" id="block-block-41">
# <h2 style="text-align:center;">Announcements for the UMN Research Community</h2>
# <div style="box-sizing: border-box;width: 50%; display: block;margin-top: 1.5rem;margin-left: auto;margin-right: auto;padding: 1.5rem 1rem 1rem 1rem;border: 1px solid #ddd;background-color: #F0F0F0;box-shadow: 0 0 15px 0 rgb(0 0 0 / 15%);overflow: hidden;text-align: center;vertical-align: middle;">
# <p><strong> <a href="https://mcphzdmd56g8qjv0xcx4wnrpgccm.pub.sfmc-content.com/hqmqzeuhfvq" target="_blank">Sign up for the <em>UMN Research</em> newsletter &gt;</a></strong></p></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section> <footer class="site-footer">
# <div class="footer-navitgation">
# <div class="row">
# <div class="column medium-4 large-3">
# </div>
# <div class="column medium-4 large-3">
# <div class="region region-ovpr-footer-info">
# <div class="block block-views first last odd" id="block-views-179cfed3f1fd19cc3baa2b014cf2a8e2">
# <div class="view view-footer-contact-information-main-ovpr view-id-footer_contact_information_main_ovpr view-display-id-block view-dom-id-052409fd04b12311dabb473fc35e82e7">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# <h3 class="site-name">Office of the Vice President for Research</h3>
# <address>
# <div class="field field-name-field-unit-address field-type-addressfield field-label-hidden"><div class="field-items"><div class="field-item even"><div class="street-block"><div class="thoroughfare">420 Johnston Hall</div><div class="premise">101 Pleasant St. SE</div></div><div class="addressfield-container-inline locality-block country-US"><span class="locality">Minneapolis</span>, <span class="state">MN</span> <span class="postal-code">55455</span></div></div></div></div></address>
# <div class="field field-name-field-unit-email field-type-email field-label-inline clearfix"><div class="field-label">Email: </div><div class="field-items"><div class="field-item even"><a href="mailto:research@umn.edu">research@umn.edu</a></div></div></div><div class="field field-name-field-unit-voice field-type-phone field-label-inline clearfix"><div class="field-label">Phone: </div><div class="field-items"><div class="field-item even">(612) 625-3394</div></div></div> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="column medium-4 large-6 medium-text-right">
# <div class="region region-ovpr-footer-menu">
# <div class="block block-menu first last odd" id="block-menu-menu-ovpr-footer-links" role="navigation">
# <ul class="menu vertical"><li class="menu__item is-leaf first leaf"><a class="menu__link" href="http://research.umn.edu/" title="">OVPR Home</a></li>
# <li class="menu__item is-leaf leaf"><a class="menu__link" href="/website-comments-feedback" title="">Website Feedback/Questions</a></li>
# <li class="menu__item is-leaf leaf"><a class="menu__link" href="http://campusmaps.umn.edu/" title="">Maps &amp; Directions</a></li>
# <li class="menu__item is-leaf last leaf"><a class="menu__link" href="http://www.pts.umn.edu/" title="">Parking &amp; Transportation</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-attribution">
# <div class="row">
# <div class="column medium-6">
# </div>
# <div class="column medium-3 medium-text-right">
# <ul class="menu vertical">
# <li><a href="#" id="top">Back to Top</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="footer-copy-text">
# <div class="row column text-center" div="">
# <div class="region region-ovpr-footer-legal">
# <div class="block block-block first last odd" id="block-block-6">
# <p style="text-align:center">© 2018 Regents of the University of Minnesota. All rights reserved. The University of Minnesota is an equal opportunity educator and employer.</p>
# <p style="text-align:center"><a href="http://privacy.umn.edu/" rel="nofollow">Privacy Statement</a><br/><a href="http://oit-drupal-prd-web.oit.umn.edu/indexAccess.php?ref_url=https://twin-cities.umn.edu/content/home" rel="nofollow">Report Accessibility Concerns</a></p>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <script src="https://research.umn.edu/sites/research.umn.edu/files/js/js_29qYXJz8NLGg8Aomg-RZPjJcj9yEdEst1BMZ9gZbs-4.js"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
# (function() {
#  var sz = document.createElement('script'); sz.type = 'text/javascript'; sz.async = true;
#  sz.src = '//siteimproveanalytics.com/js/siteanalyze_6039208.js';
#  var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sz, s);
# })();
# /*]]>*/
# </script>
# </body>
# </html>

# %%
type(proc)
# Out:
# bs4.BeautifulSoup

# %%
proc.select("div")
# Out:
# [<div class="admin-page-tools">
#  </div>,
#  <div class="printer"><div class="left"></div><div class="right">University of Minnesota<!-- br />http://twin-cities.umn.edu/<br />612-625-5000 --></div></div>,
#  <div class="left"></div>,
#  <div class="right">University of Minnesota<!-- br />http://twin-cities.umn.edu/<br />612-625-5000 --></div>,
#  <div class="umnhf" id="umnhf-h-mast">
#  <a class="umnhf" href="http://twin-cities.umn.edu/" id="umnhf-h-logo"><span>Go to the U of M home page</span></a>
#  <ul class="umnhf" id="umnhf-h-ql">
#  <li><a href="http://onestop.umn.edu/">One Stop</a></li>
#  <li class="umnhf"><a href="https://www.myu.umn.edu/">MyU <span></span></a></li>
#  </ul>
#  <!-- Button below is for dropdown toggle, only visible on mobile screens. If using
#                          a non-dropdown version you can delete this tag -->
#  <button class="umnhf" id="umnhf-m-search">Search</button>
#  <form action="//search.umn.edu/tc/" class="umnhf" id="umnhf-h-search" method="get" role="search" title="Search Websites and People">
#  <label class="umnhf" for="umnhf-h-st">Search</label>
#  <input class="umnhf" id="umnhf-h-st" name="q" type="text"/>
#  <label class="umnhf" for="umnhf-h-sb">Submit search query</label>
#  <input class="umnhf" id="umnhf-h-sb" type="submit" value=""/>
#  </form>
#  </div>,
#  <div class="top-bar secondary-nav">
#  <div class="row column">
#  <div class="region region-ovpr-back-to-ovpr">
#  <h3 class="header-return-link"><a href="/"><svg height="11px" version="1.1" viewbox="0 0 12 11" width="12px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <g fill="none" fill-rule="evenodd" id="Final-Designs" stroke="none" stroke-width="1">
#  <g fill="#FFFFFF" id="OVPR-SubSite_v4" transform="translate(-135.000000, -65.000000)">
#  <g id="OVPR-Header" transform="translate(0.000000, 49.000000)">
#  <g id="ic_home_black_24px" transform="translate(135.000000, 16.000000)">
#  <g id="Group">
#  <polygon id="Shape" points="4.8 10.7666667 4.8 6.96666667 7.2 6.96666667 7.2 10.7666667 10.2 10.7666667 10.2 5.7 12 5.7 6 0 0 5.7 1.8 5.7 1.8 10.7666667"></polygon>
#  </g>
#  </g>
#  </g>
#  </g>
#  </g>
#  </svg>Office of the Vice President for Research</a></h3>
#  </div>
#  <div class="top-bar-left">
#  <div class="region region-blog-header">
#  <div class="block block-imageblock first last odd" id="block-imageblock-1">
#  <div class="block-image">
#  <a class="imageblock-link" href="/inquiry" target="_self"><img alt="Inquiry Blog Header" class="imageblock-image" src="https://research.umn.edu/sites/research.umn.edu/files/styles/large/public/imageblock/inquiry-png.png?itok=X2uCHs5o" title="Inquiry Blog Header"/></a> </div>
#  </div>
#  </div>
#  </div>
#  <div class="top-bar-right">
#  <div class="hide-for-small show-for-large">
#  <div class="region region-ovpr-util-menu">
#  <div class="block block-menu-block first last odd" id="block-menu-block-11" role="navigation">
#  <div class="menu-block-wrapper menu-block-11 menu-name-menu-inquiry-blog-menu parent-mlid-0 menu-level-2">
#  <ul class="menu"><li class="menu__item is-leaf first last leaf menu-mlid-24876"><a class="menu__link" href="/inquiry/about-us">About Us</a></li>
#  </ul></div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row column">
#  <div class="region region-ovpr-back-to-ovpr">
#  <h3 class="header-return-link"><a href="/"><svg height="11px" version="1.1" viewbox="0 0 12 11" width="12px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <g fill="none" fill-rule="evenodd" id="Final-Designs" stroke="none" stroke-width="1">
#  <g fill="#FFFFFF" id="OVPR-SubSite_v4" transform="translate(-135.000000, -65.000000)">
#  <g id="OVPR-Header" transform="translate(0.000000, 49.000000)">
#  <g id="ic_home_black_24px" transform="translate(135.000000, 16.000000)">
#  <g id="Group">
#  <polygon id="Shape" points="4.8 10.7666667 4.8 6.96666667 7.2 6.96666667 7.2 10.7666667 10.2 10.7666667 10.2 5.7 12 5.7 6 0 0 5.7 1.8 5.7 1.8 10.7666667"></polygon>
#  </g>
#  </g>
#  </g>
#  </g>
#  </g>
#  </svg>Office of the Vice President for Research</a></h3>
#  </div>
#  <div class="top-bar-left">
#  <div class="region region-blog-header">
#  <div class="block block-imageblock first last odd" id="block-imageblock-1">
#  <div class="block-image">
#  <a class="imageblock-link" href="/inquiry" target="_self"><img alt="Inquiry Blog Header" class="imageblock-image" src="https://research.umn.edu/sites/research.umn.edu/files/styles/large/public/imageblock/inquiry-png.png?itok=X2uCHs5o" title="Inquiry Blog Header"/></a> </div>
#  </div>
#  </div>
#  </div>
#  <div class="top-bar-right">
#  <div class="hide-for-small show-for-large">
#  <div class="region region-ovpr-util-menu">
#  <div class="block block-menu-block first last odd" id="block-menu-block-11" role="navigation">
#  <div class="menu-block-wrapper menu-block-11 menu-name-menu-inquiry-blog-menu parent-mlid-0 menu-level-2">
#  <ul class="menu"><li class="menu__item is-leaf first last leaf menu-mlid-24876"><a class="menu__link" href="/inquiry/about-us">About Us</a></li>
#  </ul></div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="region region-ovpr-back-to-ovpr">
#  <h3 class="header-return-link"><a href="/"><svg height="11px" version="1.1" viewbox="0 0 12 11" width="12px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <g fill="none" fill-rule="evenodd" id="Final-Designs" stroke="none" stroke-width="1">
#  <g fill="#FFFFFF" id="OVPR-SubSite_v4" transform="translate(-135.000000, -65.000000)">
#  <g id="OVPR-Header" transform="translate(0.000000, 49.000000)">
#  <g id="ic_home_black_24px" transform="translate(135.000000, 16.000000)">
#  <g id="Group">
#  <polygon id="Shape" points="4.8 10.7666667 4.8 6.96666667 7.2 6.96666667 7.2 10.7666667 10.2 10.7666667 10.2 5.7 12 5.7 6 0 0 5.7 1.8 5.7 1.8 10.7666667"></polygon>
#  </g>
#  </g>
#  </g>
#  </g>
#  </g>
#  </svg>Office of the Vice President for Research</a></h3>
#  </div>,
#  <div class="top-bar-left">
#  <div class="region region-blog-header">
#  <div class="block block-imageblock first last odd" id="block-imageblock-1">
#  <div class="block-image">
#  <a class="imageblock-link" href="/inquiry" target="_self"><img alt="Inquiry Blog Header" class="imageblock-image" src="https://research.umn.edu/sites/research.umn.edu/files/styles/large/public/imageblock/inquiry-png.png?itok=X2uCHs5o" title="Inquiry Blog Header"/></a> </div>
#  </div>
#  </div>
#  </div>,
#  <div class="region region-blog-header">
#  <div class="block block-imageblock first last odd" id="block-imageblock-1">
#  <div class="block-image">
#  <a class="imageblock-link" href="/inquiry" target="_self"><img alt="Inquiry Blog Header" class="imageblock-image" src="https://research.umn.edu/sites/research.umn.edu/files/styles/large/public/imageblock/inquiry-png.png?itok=X2uCHs5o" title="Inquiry Blog Header"/></a> </div>
#  </div>
#  </div>,
#  <div class="block block-imageblock first last odd" id="block-imageblock-1">
#  <div class="block-image">
#  <a class="imageblock-link" href="/inquiry" target="_self"><img alt="Inquiry Blog Header" class="imageblock-image" src="https://research.umn.edu/sites/research.umn.edu/files/styles/large/public/imageblock/inquiry-png.png?itok=X2uCHs5o" title="Inquiry Blog Header"/></a> </div>
#  </div>,
#  <div class="block-image">
#  <a class="imageblock-link" href="/inquiry" target="_self"><img alt="Inquiry Blog Header" class="imageblock-image" src="https://research.umn.edu/sites/research.umn.edu/files/styles/large/public/imageblock/inquiry-png.png?itok=X2uCHs5o" title="Inquiry Blog Header"/></a> </div>,
#  <div class="top-bar-right">
#  <div class="hide-for-small show-for-large">
#  <div class="region region-ovpr-util-menu">
#  <div class="block block-menu-block first last odd" id="block-menu-block-11" role="navigation">
#  <div class="menu-block-wrapper menu-block-11 menu-name-menu-inquiry-blog-menu parent-mlid-0 menu-level-2">
#  <ul class="menu"><li class="menu__item is-leaf first last leaf menu-mlid-24876"><a class="menu__link" href="/inquiry/about-us">About Us</a></li>
#  </ul></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="hide-for-small show-for-large">
#  <div class="region region-ovpr-util-menu">
#  <div class="block block-menu-block first last odd" id="block-menu-block-11" role="navigation">
#  <div class="menu-block-wrapper menu-block-11 menu-name-menu-inquiry-blog-menu parent-mlid-0 menu-level-2">
#  <ul class="menu"><li class="menu__item is-leaf first last leaf menu-mlid-24876"><a class="menu__link" href="/inquiry/about-us">About Us</a></li>
#  </ul></div>
#  </div>
#  </div>
#  </div>,
#  <div class="region region-ovpr-util-menu">
#  <div class="block block-menu-block first last odd" id="block-menu-block-11" role="navigation">
#  <div class="menu-block-wrapper menu-block-11 menu-name-menu-inquiry-blog-menu parent-mlid-0 menu-level-2">
#  <ul class="menu"><li class="menu__item is-leaf first last leaf menu-mlid-24876"><a class="menu__link" href="/inquiry/about-us">About Us</a></li>
#  </ul></div>
#  </div>
#  </div>,
#  <div class="block block-menu-block first last odd" id="block-menu-block-11" role="navigation">
#  <div class="menu-block-wrapper menu-block-11 menu-name-menu-inquiry-blog-menu parent-mlid-0 menu-level-2">
#  <ul class="menu"><li class="menu__item is-leaf first last leaf menu-mlid-24876"><a class="menu__link" href="/inquiry/about-us">About Us</a></li>
#  </ul></div>
#  </div>,
#  <div class="menu-block-wrapper menu-block-11 menu-name-menu-inquiry-blog-menu parent-mlid-0 menu-level-2">
#  <ul class="menu"><li class="menu__item is-leaf first last leaf menu-mlid-24876"><a class="menu__link" href="/inquiry/about-us">About Us</a></li>
#  </ul></div>,
#  <div class="content-wrapper">
#  <section class="row column">
#  <nav aria-label="You are here:" role="navigation">
#  <h2 class="element-invisible">You are here</h2><div class="breadcrumb"><span class="inline odd first"><a href="/">Home</a></span> <span class="delimiter">»</span> <span class="inline even"><a href="/inquiry">Inquiry</a></span> <span class="delimiter">»</span> <span class="inline odd last">Blog Post Listing</span></div> </nav>
#  </section> <div class="main">
#  <section class="page-content">
#  <div class="row">
#  <div class="small-12 column medium-10 large-9 small-centered">
#  <a class="sr-only sr-only-focusable" id="skip-to-main-content" name="skip-to-main-content" tabindex="-1"></a>
#  <div class="view view-ovpr-blog-post-listing view-id-ovpr_blog_post_listing view-display-id-page_1 view-dom-id-488237d98a29fee6b0110f7daaa04646">
#  <div class="view-filters">
#  <form accept-charset="UTF-8" action="/inquiry/posts" id="views-exposed-form-ovpr-blog-post-listing-page-1" method="get"><div>
#  <div class="callout filter">
#  <div class="views-exposed-form">
#  <div class="views-exposed-widgets clearfix">
#  <div class="views-exposed-widget views-widget-filter-field_blog_post_categories_tid" id="edit-category-wrapper">
#  <label for="edit-category">
#                  Categories              </label>
#  <div class="views-widget">
#  <div class="form-item form-type-select form-item-category">
#  <select class="form-select" id="edit-category" name="category"><option selected="selected" value="All">- Any -</option><option value="41">Infrastructure &amp; Capabilities</option><option value="31">Research &amp; Discovery</option><option value="36">Vision &amp; Impact</option><option value="26">Business &amp; Technology</option></select>
#  </div>
#  </div>
#  </div>
#  <div class="views-exposed-widget views-widget-filter-field_blog_post_contributor_target_id" id="edit-contributor-wrapper">
#  <label for="edit-contributor">
#                  Contributor              </label>
#  <div class="views-widget">
#  <div class="form-item form-type-select form-item-contributor">
#  <select class="form-select" id="edit-contributor" name="contributor"><option selected="selected" value="All">- Any -</option><option value="1126">Contributing Writer</option><option value="7331">Dan Gilchrist</option><option value="1111">Deane Morrison</option><option value="191">Erin Dennis</option><option value="186">Kevin Coss</option><option value="7046">Kirsten Gray</option><option value="1121">Meher Khan</option><option value="8951">Vaughn Schmid</option></select>
#  </div>
#  </div>
#  </div>
#  <div class="views-exposed-widget views-submit-button">
#  <input class="form-submit" id="edit-submit-ovpr-blog-post-listing" type="submit" value="Filter"> </input></div>
#  </div>
#  </div>
#  </div></div></form> </div>
#  <div class="view-content">
#  <div class="views-row views-row-1 views-row-odd views-row-first">
#  <div class="post blog-post-teaser">
#  <div class="row">
#  <!-- Image -->
#  <div class="post-media medium-4 column">
#  <a href="/inquiry/post/sunsetting-inquiry-introducing-umn-research">
#  <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/sunsetting-inquiry-introducing-umn-research"><img alt="Sun setting over a prarie scene" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/inquiry-sunset-istock-1401293030.png?itok=HtY2zB6H" width="600"/></a></div></div></div> </a>
#  </div>
#  <div class="post-text medium-8 column">
#  <!-- Headline -->
#  <h2 class="post-headline"><a href="/inquiry/post/sunsetting-inquiry-introducing-umn-research">Sunsetting Inquiry, Introducing UMN Research</a></h2>
#  <!-- Blog Date -->
#  <div class="events-meta">
#  <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">August 1, 2022</span></div></div></div> </div>
#  <!-- Contributor -->
#  <!-- Teaser -->
#  <div class="post-teaser">
#  <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p>After eight productive years, we are phasing out the <em>Inquiry</em> blog and launching a new monthly newsletter focused on news, information, and resources for our systemwide research community.</p>
#  </div></div></div> </div>
#  <!-- Button -->
#  <a class="button secondary button-arrow button-wide" href="/inquiry/post/sunsetting-inquiry-introducing-umn-research">Continue Reading</a>
#  <!-- Category -->
#  <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
#  <div class="field-label">Categories: </div>
#  <div class="field-items">
#  <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="views-row views-row-2 views-row-even">
#  <div class="post blog-post-teaser">
#  <div class="row">
#  <!-- Image -->
#  <div class="post-media medium-4 column">
#  <a href="/inquiry/post/community-engaged-research-spurs-change-policy-domestic-violence-colombia">
#  <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/community-engaged-research-spurs-change-policy-domestic-violence-colombia"><img alt="Dr. Friedemann-Sanchez and Dr. Grieve sitting at a table together." height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-friedemann-sanchez_and_grieve.png?itok=3AYbi5_X" width="600"/></a></div></div></div> </a>
#  </div>
#  <div class="post-text medium-8 column">
#  <!-- Headline -->
#  <h2 class="post-headline"><a href="/inquiry/post/community-engaged-research-spurs-change-policy-domestic-violence-colombia">Community-Engaged Research Spurs Change in Policy on Domestic Violence in Colombia</a></h2>
#  <!-- Blog Date -->
#  <div class="events-meta">
#  <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">December 21, 2021</span></div></div></div> </div>
#  <!-- Contributor -->
#  <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
#  <!-- Teaser -->
#  <div class="post-teaser">
#  <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p>In 2018, two University of Minnesota researchers traveled to a United Nations council meeting to advocate for changes to address an epidemic of violence against women in Colombia.</p>
#  </div></div></div> </div>
#  <!-- Button -->
#  <a class="button secondary button-arrow button-wide" href="/inquiry/post/community-engaged-research-spurs-change-policy-domestic-violence-colombia">Continue Reading</a>
#  <!-- Category -->
#  <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
#  <div class="field-label">Categories: </div>
#  <div class="field-items">
#  <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="views-row views-row-3 views-row-odd">
#  <div class="post blog-post-teaser">
#  <div class="row">
#  <!-- Image -->
#  <div class="post-media medium-4 column">
#  <a href="/inquiry/post/getting-root-health-disparities-kidney-disease">
#  <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/getting-root-health-disparities-kidney-disease"><img alt="Senior man speaks with a health care provider while looking at a digital display" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-medication-management.png?itok=Aw7-AduA" width="600"/></a></div></div></div> </a>
#  </div>
#  <div class="post-text medium-8 column">
#  <!-- Headline -->
#  <h2 class="post-headline"><a href="/inquiry/post/getting-root-health-disparities-kidney-disease">Getting to the Root of Health Disparities in Kidney Disease</a></h2>
#  <!-- Blog Date -->
#  <div class="events-meta">
#  <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">October 28, 2021</span></div></div></div> </div>
#  <!-- Contributor -->
#  <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
#  <!-- Teaser -->
#  <div class="post-teaser">
#  <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p><span>Researchers aim to help train pharmacists and educate patients with the goal of improving medication outcomes for groups with higher rates of kidney failure.</span></p>
#  </div></div></div> </div>
#  <!-- Button -->
#  <a class="button secondary button-arrow button-wide" href="/inquiry/post/getting-root-health-disparities-kidney-disease">Continue Reading</a>
#  <!-- Category -->
#  <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
#  <div class="field-label">Categories: </div>
#  <div class="field-items">
#  <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="views-row views-row-4 views-row-even">
#  <div class="post blog-post-teaser">
#  <div class="row">
#  <!-- Image -->
#  <div class="post-media medium-4 column">
#  <a href="/inquiry/post/startup-scales-eco-friendly-ingredients-cleaning-personal-care">
#  <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/startup-scales-eco-friendly-ingredients-cleaning-personal-care"><img alt="Sironix banner in a laboratory space" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-sironix-1.png?itok=chRAGh0C" width="600"/></a></div></div></div> </a>
#  </div>
#  <div class="post-text medium-8 column">
#  <!-- Headline -->
#  <h2 class="post-headline"><a href="/inquiry/post/startup-scales-eco-friendly-ingredients-cleaning-personal-care">Startup Scales Up Eco-Friendly Ingredients for Cleaning, Personal Care</a></h2>
#  <!-- Blog Date -->
#  <div class="events-meta">
#  <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">October 27, 2021</span></div></div></div> </div>
#  <!-- Contributor -->
#  <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
#  <!-- Teaser -->
#  <div class="post-teaser">
#  <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p><span>Sironix Renewables uses a patented method to make nontoxic, sustainably-sourced surfactants that replace their counterparts made from petroleum.</span></p>
#  </div></div></div> </div>
#  <!-- Button -->
#  <a class="button secondary button-arrow button-wide" href="/inquiry/post/startup-scales-eco-friendly-ingredients-cleaning-personal-care">Continue Reading</a>
#  <!-- Category -->
#  <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
#  <div class="field-label">Categories: </div>
#  <div class="field-items">
#  <a href="/inquiry/posts?category=26">Business &amp; Technology</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="views-row views-row-5 views-row-odd">
#  <div class="post blog-post-teaser">
#  <div class="row">
#  <!-- Image -->
#  <div class="post-media medium-4 column">
#  <a href="/inquiry/post/contemporary-history-brings-insight-asylum-cases">
#  <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/contemporary-history-brings-insight-asylum-cases"><img alt="Border crossing checkpoint from Mexico to US" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-border-entry.png?itok=N1KE7y_3" width="600"/></a></div></div></div> </a>
#  </div>
#  <div class="post-text medium-8 column">
#  <!-- Headline -->
#  <h2 class="post-headline"><a href="/inquiry/post/contemporary-history-brings-insight-asylum-cases">Contemporary History Brings Insight to Asylum Cases</a></h2>
#  <!-- Blog Date -->
#  <div class="events-meta">
#  <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">October 27, 2021</span></div></div></div> </div>
#  <!-- Contributor -->
#  <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
#  <!-- Teaser -->
#  <div class="post-teaser">
#  <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p><span>As an expert witness on federal immigration court cases, Patrick McNamara provides insight into violence directly and indirectly related to drug cartels.</span></p>
#  </div></div></div> </div>
#  <!-- Button -->
#  <a class="button secondary button-arrow button-wide" href="/inquiry/post/contemporary-history-brings-insight-asylum-cases">Continue Reading</a>
#  <!-- Category -->
#  <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
#  <div class="field-label">Categories: </div>
#  <div class="field-items">
#  <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="views-row views-row-6 views-row-even">
#  <div class="post blog-post-teaser">
#  <div class="row">
#  <!-- Image -->
#  <div class="post-media medium-4 column">
#  <a href="/inquiry/post/mapping-out-life-ideas-champion-humanities">
#  <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/mapping-out-life-ideas-champion-humanities"><img alt="Edward Said portrait" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-edward-said.png?itok=5tCNc2mm" width="600"/></a></div></div></div> </a>
#  </div>
#  <div class="post-text medium-8 column">
#  <!-- Headline -->
#  <h2 class="post-headline"><a href="/inquiry/post/mapping-out-life-ideas-champion-humanities">Mapping Out the Life &amp; Ideas of a Champion of the Humanities</a></h2>
#  <!-- Blog Date -->
#  <div class="events-meta">
#  <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">October 27, 2021</span></div></div></div> </div>
#  <!-- Contributor -->
#  <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
#  <!-- Teaser -->
#  <div class="post-teaser">
#  <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p><span>The first comprehensive biography of Edward Said explores how the public figure's intellectual breadth and influence developed over the years.</span></p>
#  </div></div></div> </div>
#  <!-- Button -->
#  <a class="button secondary button-arrow button-wide" href="/inquiry/post/mapping-out-life-ideas-champion-humanities">Continue Reading</a>
#  <!-- Category -->
#  <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
#  <div class="field-label">Categories: </div>
#  <div class="field-items">
#  <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="views-row views-row-7 views-row-odd">
#  <div class="post blog-post-teaser">
#  <div class="row">
#  <!-- Image -->
#  <div class="post-media medium-4 column">
#  <a href="/inquiry/post/saving-oaks-remote-sensing-could-detect-invasive-fungus-earlier">
#  <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/saving-oaks-remote-sensing-could-detect-invasive-fungus-earlier"><img alt="Oak tree in a sunny field" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-oak-tree.png?itok=sdNoiGMN" width="600"/></a></div></div></div> </a>
#  </div>
#  <div class="post-text medium-8 column">
#  <!-- Headline -->
#  <h2 class="post-headline"><a href="/inquiry/post/saving-oaks-remote-sensing-could-detect-invasive-fungus-earlier">Saving Oaks: Remote Sensing Could Detect Invasive Fungus Earlier</a></h2>
#  <!-- Blog Date -->
#  <div class="events-meta">
#  <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">September 30, 2021</span></div></div></div> </div>
#  <!-- Contributor -->
#  <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
#  <!-- Teaser -->
#  <div class="post-teaser">
#  <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p><span>Hyperspectral imaging may provide a quicker and more accurate way to detect trees infected with oak wilt and inform efforts to stanch the disease's spread.</span></p>
#  </div></div></div> </div>
#  <!-- Button -->
#  <a class="button secondary button-arrow button-wide" href="/inquiry/post/saving-oaks-remote-sensing-could-detect-invasive-fungus-earlier">Continue Reading</a>
#  <!-- Category -->
#  <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
#  <div class="field-label">Categories: </div>
#  <div class="field-items">
#  <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="views-row views-row-8 views-row-even">
#  <div class="post blog-post-teaser">
#  <div class="row">
#  <!-- Image -->
#  <div class="post-media medium-4 column">
#  <a href="/inquiry/post/globalization-bane-traditional-languages-and-skills">
#  <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/globalization-bane-traditional-languages-and-skills"><img alt="Adults sitting wearing traditional costumes and children wearing school uniforms" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-papuanewguinea.png?itok=caZXQ6u4" width="600"/></a></div></div></div> </a>
#  </div>
#  <div class="post-text medium-8 column">
#  <!-- Headline -->
#  <h2 class="post-headline"><a href="/inquiry/post/globalization-bane-traditional-languages-and-skills">Globalization, the Bane of Traditional Languages and Skills</a></h2>
#  <!-- Blog Date -->
#  <div class="events-meta">
#  <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">September 30, 2021</span></div></div></div> </div>
#  <!-- Contributor -->
#  <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Deane Morrison</p></div></div></div>
#  <!-- Teaser -->
#  <div class="post-teaser">
#  <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p class="Body"><span>A sizable gap in indigenous language fluency and traditional practices has opened up between teenage students and their parents in Papua New Guinea.</span></p>
#  </div></div></div> </div>
#  <!-- Button -->
#  <a class="button secondary button-arrow button-wide" href="/inquiry/post/globalization-bane-traditional-languages-and-skills">Continue Reading</a>
#  <!-- Category -->
#  <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
#  <div class="field-label">Categories: </div>
#  <div class="field-items">
#  <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="views-row views-row-9 views-row-odd">
#  <div class="post blog-post-teaser">
#  <div class="row">
#  <!-- Image -->
#  <div class="post-media medium-4 column">
#  <a href="/inquiry/post/research-purpose-new-model-combines-philosophy-and-science">
#  <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/research-purpose-new-model-combines-philosophy-and-science"><img alt="Multitude of blue butterflies with a single orange butterfly atop them" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-butterflies.png?itok=h5gmishv" width="600"/></a></div></div></div> </a>
#  </div>
#  <div class="post-text medium-8 column">
#  <!-- Headline -->
#  <h2 class="post-headline"><a href="/inquiry/post/research-purpose-new-model-combines-philosophy-and-science">Research on Purpose: New Model Combines Philosophy and Science</a></h2>
#  <!-- Blog Date -->
#  <div class="events-meta">
#  <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">September 27, 2021</span></div></div></div> </div>
#  <!-- Contributor -->
#  <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
#  <!-- Teaser -->
#  <div class="post-teaser">
#  <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p><span>Through nearly $15 million in Templeton Foundation funding, a new international cohort program led by a UMN philosophy researcher aims to explore purposive-looking behavior in living systems.</span></p>
#  </div></div></div> </div>
#  <!-- Button -->
#  <a class="button secondary button-arrow button-wide" href="/inquiry/post/research-purpose-new-model-combines-philosophy-and-science">Continue Reading</a>
#  <!-- Category -->
#  <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
#  <div class="field-label">Categories: </div>
#  <div class="field-items">
#  <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="views-row views-row-10 views-row-even views-row-last">
#  <div class="post blog-post-teaser">
#  <div class="row">
#  <!-- Image -->
#  <div class="post-media medium-4 column">
#  <a href="/inquiry/post/new-award-program-celebrates-impact-research-innovation">
#  <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/new-award-program-celebrates-impact-research-innovation"><img alt="Graphic reading Innovation Impact Case Award" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/innovation_main_inquiry.png?itok=76Vh7BRc" width="600"/></a></div></div></div> </a>
#  </div>
#  <div class="post-text medium-8 column">
#  <!-- Headline -->
#  <h2 class="post-headline"><a href="/inquiry/post/new-award-program-celebrates-impact-research-innovation">New Award Program Celebrates Impact of Research &amp; Innovation</a></h2>
#  <!-- Blog Date -->
#  <div class="events-meta">
#  <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">September 24, 2021</span></div></div></div> </div>
#  <!-- Contributor -->
#  <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
#  <!-- Teaser -->
#  <div class="post-teaser">
#  <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p><span>The new Innovation Impact Case Award celebrates work that solves challenges and benefits individuals, organizations, and communities.</span></p>
#  </div></div></div> </div>
#  <!-- Button -->
#  <a class="button secondary button-arrow button-wide" href="/inquiry/post/new-award-program-celebrates-impact-research-innovation">Continue Reading</a>
#  <!-- Category -->
#  <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
#  <div class="field-label">Categories: </div>
#  <div class="field-items">
#  <a href="/inquiry/posts?category=36">Vision &amp; Impact</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <h2 class="element-invisible">Pages</h2><div class="item-list"><ul class="pager"><li class="pager-current first">1</li>
#  <li class="pager-item"><a href="/inquiry/posts?page=1" title="Go to page 2">2</a></li>
#  <li class="pager-item"><a href="/inquiry/posts?page=2" title="Go to page 3">3</a></li>
#  <li class="pager-item"><a href="/inquiry/posts?page=3" title="Go to page 4">4</a></li>
#  <li class="pager-item"><a href="/inquiry/posts?page=4" title="Go to page 5">5</a></li>
#  <li class="pager-ellipsis">…</li>
#  <li class="pager-next"><a href="/inquiry/posts?page=1">Next</a></li>
#  <li class="pager-last last"><a href="/inquiry/posts?page=38">Last</a></li>
#  </ul></div>
#  </div>
#  </div>
#  </div>
#  </section>
#  </div>
#  <section class="subscribe">
#  <div class="row">
#  <div class="column small-12 medium-10 medium-centered large-centered">
#  <div class="callout large">
#  <div class="region region-ovpr-newsletter">
#  <div class="block block-block first last odd" id="block-block-41">
#  <h2 style="text-align:center;">Announcements for the UMN Research Community</h2>
#  <div style="box-sizing: border-box;width: 50%; display: block;margin-top: 1.5rem;margin-left: auto;margin-right: auto;padding: 1.5rem 1rem 1rem 1rem;border: 1px solid #ddd;background-color: #F0F0F0;box-shadow: 0 0 15px 0 rgb(0 0 0 / 15%);overflow: hidden;text-align: center;vertical-align: middle;">
#  <p><strong> <a href="https://mcphzdmd56g8qjv0xcx4wnrpgccm.pub.sfmc-content.com/hqmqzeuhfvq" target="_blank">Sign up for the <em>UMN Research</em> newsletter &gt;</a></strong></p></div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section> <footer class="site-footer">
#  <div class="footer-navitgation">
#  <div class="row">
#  <div class="column medium-4 large-3">
#  </div>
#  <div class="column medium-4 large-3">
#  <div class="region region-ovpr-footer-info">
#  <div class="block block-views first last odd" id="block-views-179cfed3f1fd19cc3baa2b014cf2a8e2">
#  <div class="view view-footer-contact-information-main-ovpr view-id-footer_contact_information_main_ovpr view-display-id-block view-dom-id-052409fd04b12311dabb473fc35e82e7">
#  <div class="view-content">
#  <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
#  <h3 class="site-name">Office of the Vice President for Research</h3>
#  <address>
#  <div class="field field-name-field-unit-address field-type-addressfield field-label-hidden"><div class="field-items"><div class="field-item even"><div class="street-block"><div class="thoroughfare">420 Johnston Hall</div><div class="premise">101 Pleasant St. SE</div></div><div class="addressfield-container-inline locality-block country-US"><span class="locality">Minneapolis</span>, <span class="state">MN</span> <span class="postal-code">55455</span></div></div></div></div></address>
#  <div class="field field-name-field-unit-email field-type-email field-label-inline clearfix"><div class="field-label">Email: </div><div class="field-items"><div class="field-item even"><a href="mailto:research@umn.edu">research@umn.edu</a></div></div></div><div class="field field-name-field-unit-voice field-type-phone field-label-inline clearfix"><div class="field-label">Phone: </div><div class="field-items"><div class="field-item even">(612) 625-3394</div></div></div> </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="column medium-4 large-6 medium-text-right">
#  <div class="region region-ovpr-footer-menu">
#  <div class="block block-menu first last odd" id="block-menu-menu-ovpr-footer-links" role="navigation">
#  <ul class="menu vertical"><li class="menu__item is-leaf first leaf"><a class="menu__link" href="http://research.umn.edu/" title="">OVPR Home</a></li>
#  <li class="menu__item is-leaf leaf"><a class="menu__link" href="/website-comments-feedback" title="">Website Feedback/Questions</a></li>
#  <li class="menu__item is-leaf leaf"><a class="menu__link" href="http://campusmaps.umn.edu/" title="">Maps &amp; Directions</a></li>
#  <li class="menu__item is-leaf last leaf"><a class="menu__link" href="http://www.pts.umn.edu/" title="">Parking &amp; Transportation</a></li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="footer-attribution">
#  <div class="row">
#  <div class="column medium-6">
#  </div>
#  <div class="column medium-3 medium-text-right">
#  <ul class="menu vertical">
#  <li><a href="#" id="top">Back to Top</a></li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <div class="footer-copy-text">
#  <div class="row column text-center" div="">
#  <div class="region region-ovpr-footer-legal">
#  <div class="block block-block first last odd" id="block-block-6">
#  <p style="text-align:center">© 2018 Regents of the University of Minnesota. All rights reserved. The University of Minnesota is an equal opportunity educator and employer.</p>
#  <p style="text-align:center"><a href="http://privacy.umn.edu/" rel="nofollow">Privacy Statement</a><br/><a href="http://oit-drupal-prd-web.oit.umn.edu/indexAccess.php?ref_url=https://twin-cities.umn.edu/content/home" rel="nofollow">Report Accessibility Concerns</a></p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </footer>
#  </div>,
#  <div class="breadcrumb"><span class="inline odd first"><a href="/">Home</a></span> <span class="delimiter">»</span> <span class="inline even"><a href="/inquiry">Inquiry</a></span> <span class="delimiter">»</span> <span class="inline odd last">Blog Post Listing</span></div>,
#  <div class="main">
#  <section class="page-content">
#  <div class="row">
#  <div class="small-12 column medium-10 large-9 small-centered">
#  <a class="sr-only sr-only-focusable" id="skip-to-main-content" name="skip-to-main-content" tabindex="-1"></a>
#  <div class="view view-ovpr-blog-post-listing view-id-ovpr_blog_post_listing view-display-id-page_1 view-dom-id-488237d98a29fee6b0110f7daaa04646">
#  <div class="view-filters">
#  <form accept-charset="UTF-8" action="/inquiry/posts" id="views-exposed-form-ovpr-blog-post-listing-page-1" method="get"><div>
#  <div class="callout filter">
#  <div class="views-exposed-form">
#  <div class="views-exposed-widgets clearfix">
#  <div class="views-exposed-widget views-widget-filter-field_blog_post_categories_tid" id="edit-category-wrapper">
#  <label for="edit-category">
#                  Categories              </label>
#  <div class="views-widget">
#  <div class="form-item form-type-select form-item-category">
#  <select class="form-select" id="edit-category" name="category"><option selected="selected" value="All">- Any -</option><option value="41">Infrastructure &amp; Capabilities</option><option value="31">Research &amp; Discovery</option><option value="36">Vision &amp; Impact</option><option value="26">Business &amp; Technology</option></select>
#  </div>
#  </div>
#  </div>
#  <div class="views-exposed-widget views-widget-filter-field_blog_post_contributor_target_id" id="edit-contributor-wrapper">
#  <label for="edit-contributor">
#                  Contributor              </label>
#  <div class="views-widget">
#  <div class="form-item form-type-select form-item-contributor">
#  <select class="form-select" id="edit-contributor" name="contributor"><option selected="selected" value="All">- Any -</option><option value="1126">Contributing Writer</option><option value="7331">Dan Gilchrist</option><option value="1111">Deane Morrison</option><option value="191">Erin Dennis</option><option value="186">Kevin Coss</option><option value="7046">Kirsten Gray</option><option value="1121">Meher Khan</option><option value="8951">Vaughn Schmid</option></select>
#  </div>
#  </div>
#  </div>
#  <div class="views-exposed-widget views-submit-button">
#  <input class="form-submit" id="edit-submit-ovpr-blog-post-listing" type="submit" value="Filter"> </input></div>
#  </div>
#  </div>
#  </div></div></form> </div>
#  <div class="view-content">
#  <div class="views-row views-row-1 views-row-odd views-row-first">
#  <div class="post blog-post-teaser">
#  <div class="row">
#  <!-- Image -->
#  <div class="post-media medium-4 column">
#  <a href="/inquiry/post/sunsetting-inquiry-introducing-umn-research">
#  <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/sunsetting-inquiry-introducing-umn-research"><img alt="Sun setting over a prarie scene" height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/inquiry-sunset-istock-1401293030.png?itok=HtY2zB6H" width="600"/></a></div></div></div> </a>
#  </div>
#  <div class="post-text medium-8 column">
#  <!-- Headline -->
#  <h2 class="post-headline"><a href="/inquiry/post/sunsetting-inquiry-introducing-umn-research">Sunsetting Inquiry, Introducing UMN Research</a></h2>
#  <!-- Blog Date -->
#  <div class="events-meta">
#  <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">August 1, 2022</span></div></div></div> </div>
#  <!-- Contributor -->
#  <!-- Teaser -->
#  <div class="post-teaser">
#  <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p>After eight productive years, we are phasing out the <em>Inquiry</em> blog and launching a new monthly newsletter focused on news, information, and resources for our systemwide research community.</p>
#  </div></div></div> </div>
#  <!-- Button -->
#  <a class="button secondary button-arrow button-wide" href="/inquiry/post/sunsetting-inquiry-introducing-umn-research">Continue Reading</a>
#  <!-- Category -->
#  <div class="post-meta"><div class="field field-name-field-blog-post-categories field-type-taxonomy-term-reference field-label-inline clearfix">
#  <div class="field-label">Categories: </div>
#  <div class="field-items">
#  <a href="/inquiry/posts?category=31">Research &amp; Discovery</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="views-row views-row-2 views-row-even">
#  <div class="post blog-post-teaser">
#  <div class="row">
#  <!-- Image -->
#  <div class="post-media medium-4 column">
#  <a href="/inquiry/post/community-engaged-research-spurs-change-policy-domestic-violence-colombia">
#  <div class="field field-name-field-blog-post-image field-type-image field-label-hidden"><div class="field-items"><div class="field-item even"><a href="/inquiry/post/community-engaged-research-spurs-change-policy-domestic-violence-colombia"><img alt="Dr. Friedemann-Sanchez and Dr. Grieve sitting at a table together." height="600" src="https://research.umn.edu/sites/research.umn.edu/files/styles/ovpr_square/public/blog-friedemann-sanchez_and_grieve.png?itok=3AYbi5_X" width="600"/></a></div></div></div> </a>
#  </div>
#  <div class="post-text medium-8 column">
#  <!-- Headline -->
#  <h2 class="post-headline"><a href="/inquiry/post/community-engaged-research-spurs-change-policy-domestic-violence-colombia">Community-Engaged Research Spurs Change in Policy on Domestic Violence in Colombia</a></h2>
#  <!-- Blog Date -->
#  <div class="events-meta">
#  <div class="field field-name-field-blog-post-date field-type-datetime field-label-hidden"><div class="field-items"><div class="field-item even"><span class="date-display-single">December 21, 2021</span></div></div></div> </div>
#  <!-- Contributor -->
#  <div class="field field-name-field-blog-post-contributor field-type-entityreference field-label-hidden"><div class="field-items"><div class="field-item even"><p class="post-author">by Kevin Coss</p></div></div></div>
#  <!-- Teaser -->
#  <div class="post-teaser">
#  <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even"><p>In 2018, two University of Minnesota researchers traveled to a United Nations council meeting to advocate for changes to address an epidemic of violence against women in Colombia.</p>
#  </div></div></div> </div>
#  <!-- Button -->
#  <a class="button secondary button-arrow button-wide" href="/inquiry/post/community-engaged-research-spurs-change-policy-domestic-violence-colombia">Continue Reading</a>
# ...
#  <div class="column medium-4 large-3">
#  <div class="region region-ovpr-footer-info">
#  <div class="block block-views first last odd" id="block-views-179cfed3f1fd19cc3baa2b014cf2a8e2">
#  <div class="view view-footer-contact-information-main-ovpr view-id-footer_contact_information_main_ovpr view-display-id-block view-dom-id-052409fd04b12311dabb473fc35e82e7">
#  <div class="view-content">
#  <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
#  <h3 class="site-name">Office of the Vice President for Research</h3>
#  <address>
#  <div class="field field-name-field-unit-address field-type-addressfield field-label-hidden"><div class="field-items"><div class="field-item even"><div class="street-block"><div class="thoroughfare">420 Johnston Hall</div><div class="premise">101 Pleasant St. SE</div></div><div class="addressfield-container-inline locality-block country-US"><span class="locality">Minneapolis</span>, <span class="state">MN</span> <span class="postal-code">55455</span></div></div></div></div></address>
#  <div class="field field-name-field-unit-email field-type-email field-label-inline clearfix"><div class="field-label">Email: </div><div class="field-items"><div class="field-item even"><a href="mailto:research@umn.edu">research@umn.edu</a></div></div></div><div class="field field-name-field-unit-voice field-type-phone field-label-inline clearfix"><div class="field-label">Phone: </div><div class="field-items"><div class="field-item even">(612) 625-3394</div></div></div> </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="region region-ovpr-footer-info">
#  <div class="block block-views first last odd" id="block-views-179cfed3f1fd19cc3baa2b014cf2a8e2">
#  <div class="view view-footer-contact-information-main-ovpr view-id-footer_contact_information_main_ovpr view-display-id-block view-dom-id-052409fd04b12311dabb473fc35e82e7">
#  <div class="view-content">
#  <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
#  <h3 class="site-name">Office of the Vice President for Research</h3>
#  <address>
#  <div class="field field-name-field-unit-address field-type-addressfield field-label-hidden"><div class="field-items"><div class="field-item even"><div class="street-block"><div class="thoroughfare">420 Johnston Hall</div><div class="premise">101 Pleasant St. SE</div></div><div class="addressfield-container-inline locality-block country-US"><span class="locality">Minneapolis</span>, <span class="state">MN</span> <span class="postal-code">55455</span></div></div></div></div></address>
#  <div class="field field-name-field-unit-email field-type-email field-label-inline clearfix"><div class="field-label">Email: </div><div class="field-items"><div class="field-item even"><a href="mailto:research@umn.edu">research@umn.edu</a></div></div></div><div class="field field-name-field-unit-voice field-type-phone field-label-inline clearfix"><div class="field-label">Phone: </div><div class="field-items"><div class="field-item even">(612) 625-3394</div></div></div> </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="block block-views first last odd" id="block-views-179cfed3f1fd19cc3baa2b014cf2a8e2">
#  <div class="view view-footer-contact-information-main-ovpr view-id-footer_contact_information_main_ovpr view-display-id-block view-dom-id-052409fd04b12311dabb473fc35e82e7">
#  <div class="view-content">
#  <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
#  <h3 class="site-name">Office of the Vice President for Research</h3>
#  <address>
#  <div class="field field-name-field-unit-address field-type-addressfield field-label-hidden"><div class="field-items"><div class="field-item even"><div class="street-block"><div class="thoroughfare">420 Johnston Hall</div><div class="premise">101 Pleasant St. SE</div></div><div class="addressfield-container-inline locality-block country-US"><span class="locality">Minneapolis</span>, <span class="state">MN</span> <span class="postal-code">55455</span></div></div></div></div></address>
#  <div class="field field-name-field-unit-email field-type-email field-label-inline clearfix"><div class="field-label">Email: </div><div class="field-items"><div class="field-item even"><a href="mailto:research@umn.edu">research@umn.edu</a></div></div></div><div class="field field-name-field-unit-voice field-type-phone field-label-inline clearfix"><div class="field-label">Phone: </div><div class="field-items"><div class="field-item even">(612) 625-3394</div></div></div> </div>
#  </div>
#  </div>
#  </div>,
#  <div class="view view-footer-contact-information-main-ovpr view-id-footer_contact_information_main_ovpr view-display-id-block view-dom-id-052409fd04b12311dabb473fc35e82e7">
#  <div class="view-content">
#  <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
#  <h3 class="site-name">Office of the Vice President for Research</h3>
#  <address>
#  <div class="field field-name-field-unit-address field-type-addressfield field-label-hidden"><div class="field-items"><div class="field-item even"><div class="street-block"><div class="thoroughfare">420 Johnston Hall</div><div class="premise">101 Pleasant St. SE</div></div><div class="addressfield-container-inline locality-block country-US"><span class="locality">Minneapolis</span>, <span class="state">MN</span> <span class="postal-code">55455</span></div></div></div></div></address>
#  <div class="field field-name-field-unit-email field-type-email field-label-inline clearfix"><div class="field-label">Email: </div><div class="field-items"><div class="field-item even"><a href="mailto:research@umn.edu">research@umn.edu</a></div></div></div><div class="field field-name-field-unit-voice field-type-phone field-label-inline clearfix"><div class="field-label">Phone: </div><div class="field-items"><div class="field-item even">(612) 625-3394</div></div></div> </div>
#  </div>
#  </div>,
#  <div class="view-content">
#  <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
#  <h3 class="site-name">Office of the Vice President for Research</h3>
#  <address>
#  <div class="field field-name-field-unit-address field-type-addressfield field-label-hidden"><div class="field-items"><div class="field-item even"><div class="street-block"><div class="thoroughfare">420 Johnston Hall</div><div class="premise">101 Pleasant St. SE</div></div><div class="addressfield-container-inline locality-block country-US"><span class="locality">Minneapolis</span>, <span class="state">MN</span> <span class="postal-code">55455</span></div></div></div></div></address>
#  <div class="field field-name-field-unit-email field-type-email field-label-inline clearfix"><div class="field-label">Email: </div><div class="field-items"><div class="field-item even"><a href="mailto:research@umn.edu">research@umn.edu</a></div></div></div><div class="field field-name-field-unit-voice field-type-phone field-label-inline clearfix"><div class="field-label">Phone: </div><div class="field-items"><div class="field-item even">(612) 625-3394</div></div></div> </div>
#  </div>,
#  <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
#  <h3 class="site-name">Office of the Vice President for Research</h3>
#  <address>
#  <div class="field field-name-field-unit-address field-type-addressfield field-label-hidden"><div class="field-items"><div class="field-item even"><div class="street-block"><div class="thoroughfare">420 Johnston Hall</div><div class="premise">101 Pleasant St. SE</div></div><div class="addressfield-container-inline locality-block country-US"><span class="locality">Minneapolis</span>, <span class="state">MN</span> <span class="postal-code">55455</span></div></div></div></div></address>
#  <div class="field field-name-field-unit-email field-type-email field-label-inline clearfix"><div class="field-label">Email: </div><div class="field-items"><div class="field-item even"><a href="mailto:research@umn.edu">research@umn.edu</a></div></div></div><div class="field field-name-field-unit-voice field-type-phone field-label-inline clearfix"><div class="field-label">Phone: </div><div class="field-items"><div class="field-item even">(612) 625-3394</div></div></div> </div>,
#  <div class="field field-name-field-unit-address field-type-addressfield field-label-hidden"><div class="field-items"><div class="field-item even"><div class="street-block"><div class="thoroughfare">420 Johnston Hall</div><div class="premise">101 Pleasant St. SE</div></div><div class="addressfield-container-inline locality-block country-US"><span class="locality">Minneapolis</span>, <span class="state">MN</span> <span class="postal-code">55455</span></div></div></div></div>,
#  <div class="field-items"><div class="field-item even"><div class="street-block"><div class="thoroughfare">420 Johnston Hall</div><div class="premise">101 Pleasant St. SE</div></div><div class="addressfield-container-inline locality-block country-US"><span class="locality">Minneapolis</span>, <span class="state">MN</span> <span class="postal-code">55455</span></div></div></div>,
#  <div class="field-item even"><div class="street-block"><div class="thoroughfare">420 Johnston Hall</div><div class="premise">101 Pleasant St. SE</div></div><div class="addressfield-container-inline locality-block country-US"><span class="locality">Minneapolis</span>, <span class="state">MN</span> <span class="postal-code">55455</span></div></div>,
#  <div class="street-block"><div class="thoroughfare">420 Johnston Hall</div><div class="premise">101 Pleasant St. SE</div></div>,
#  <div class="thoroughfare">420 Johnston Hall</div>,
#  <div class="premise">101 Pleasant St. SE</div>,
#  <div class="addressfield-container-inline locality-block country-US"><span class="locality">Minneapolis</span>, <span class="state">MN</span> <span class="postal-code">55455</span></div>,
#  <div class="field field-name-field-unit-email field-type-email field-label-inline clearfix"><div class="field-label">Email: </div><div class="field-items"><div class="field-item even"><a href="mailto:research@umn.edu">research@umn.edu</a></div></div></div>,
#  <div class="field-label">Email: </div>,
#  <div class="field-items"><div class="field-item even"><a href="mailto:research@umn.edu">research@umn.edu</a></div></div>,
#  <div class="field-item even"><a href="mailto:research@umn.edu">research@umn.edu</a></div>,
#  <div class="field field-name-field-unit-voice field-type-phone field-label-inline clearfix"><div class="field-label">Phone: </div><div class="field-items"><div class="field-item even">(612) 625-3394</div></div></div>,
#  <div class="field-label">Phone: </div>,
#  <div class="field-items"><div class="field-item even">(612) 625-3394</div></div>,
#  <div class="field-item even">(612) 625-3394</div>,
#  <div class="column medium-4 large-6 medium-text-right">
#  <div class="region region-ovpr-footer-menu">
#  <div class="block block-menu first last odd" id="block-menu-menu-ovpr-footer-links" role="navigation">
#  <ul class="menu vertical"><li class="menu__item is-leaf first leaf"><a class="menu__link" href="http://research.umn.edu/" title="">OVPR Home</a></li>
#  <li class="menu__item is-leaf leaf"><a class="menu__link" href="/website-comments-feedback" title="">Website Feedback/Questions</a></li>
#  <li class="menu__item is-leaf leaf"><a class="menu__link" href="http://campusmaps.umn.edu/" title="">Maps &amp; Directions</a></li>
#  <li class="menu__item is-leaf last leaf"><a class="menu__link" href="http://www.pts.umn.edu/" title="">Parking &amp; Transportation</a></li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="region region-ovpr-footer-menu">
#  <div class="block block-menu first last odd" id="block-menu-menu-ovpr-footer-links" role="navigation">
#  <ul class="menu vertical"><li class="menu__item is-leaf first leaf"><a class="menu__link" href="http://research.umn.edu/" title="">OVPR Home</a></li>
#  <li class="menu__item is-leaf leaf"><a class="menu__link" href="/website-comments-feedback" title="">Website Feedback/Questions</a></li>
#  <li class="menu__item is-leaf leaf"><a class="menu__link" href="http://campusmaps.umn.edu/" title="">Maps &amp; Directions</a></li>
#  <li class="menu__item is-leaf last leaf"><a class="menu__link" href="http://www.pts.umn.edu/" title="">Parking &amp; Transportation</a></li>
#  </ul>
#  </div>
#  </div>,
#  <div class="block block-menu first last odd" id="block-menu-menu-ovpr-footer-links" role="navigation">
#  <ul class="menu vertical"><li class="menu__item is-leaf first leaf"><a class="menu__link" href="http://research.umn.edu/" title="">OVPR Home</a></li>
#  <li class="menu__item is-leaf leaf"><a class="menu__link" href="/website-comments-feedback" title="">Website Feedback/Questions</a></li>
#  <li class="menu__item is-leaf leaf"><a class="menu__link" href="http://campusmaps.umn.edu/" title="">Maps &amp; Directions</a></li>
#  <li class="menu__item is-leaf last leaf"><a class="menu__link" href="http://www.pts.umn.edu/" title="">Parking &amp; Transportation</a></li>
#  </ul>
#  </div>,
#  <div class="footer-attribution">
#  <div class="row">
#  <div class="column medium-6">
#  </div>
#  <div class="column medium-3 medium-text-right">
#  <ul class="menu vertical">
#  <li><a href="#" id="top">Back to Top</a></li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="column medium-6">
#  </div>
#  <div class="column medium-3 medium-text-right">
#  <ul class="menu vertical">
#  <li><a href="#" id="top">Back to Top</a></li>
#  </ul>
#  </div>
#  </div>,
#  <div class="column medium-6">
#  </div>,
#  <div class="column medium-3 medium-text-right">
#  <ul class="menu vertical">
#  <li><a href="#" id="top">Back to Top</a></li>
#  </ul>
#  </div>,
#  <div class="footer-copy-text">
#  <div class="row column text-center" div="">
#  <div class="region region-ovpr-footer-legal">
#  <div class="block block-block first last odd" id="block-block-6">
#  <p style="text-align:center">© 2018 Regents of the University of Minnesota. All rights reserved. The University of Minnesota is an equal opportunity educator and employer.</p>
#  <p style="text-align:center"><a href="http://privacy.umn.edu/" rel="nofollow">Privacy Statement</a><br/><a href="http://oit-drupal-prd-web.oit.umn.edu/indexAccess.php?ref_url=https://twin-cities.umn.edu/content/home" rel="nofollow">Report Accessibility Concerns</a></p>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row column text-center" div="">
#  <div class="region region-ovpr-footer-legal">
#  <div class="block block-block first last odd" id="block-block-6">
#  <p style="text-align:center">© 2018 Regents of the University of Minnesota. All rights reserved. The University of Minnesota is an equal opportunity educator and employer.</p>
#  <p style="text-align:center"><a href="http://privacy.umn.edu/" rel="nofollow">Privacy Statement</a><br/><a href="http://oit-drupal-prd-web.oit.umn.edu/indexAccess.php?ref_url=https://twin-cities.umn.edu/content/home" rel="nofollow">Report Accessibility Concerns</a></p>
#  </div>
#  </div>
#  </div>,
#  <div class="region region-ovpr-footer-legal">
#  <div class="block block-block first last odd" id="block-block-6">
#  <p style="text-align:center">© 2018 Regents of the University of Minnesota. All rights reserved. The University of Minnesota is an equal opportunity educator and employer.</p>
#  <p style="text-align:center"><a href="http://privacy.umn.edu/" rel="nofollow">Privacy Statement</a><br/><a href="http://oit-drupal-prd-web.oit.umn.edu/indexAccess.php?ref_url=https://twin-cities.umn.edu/content/home" rel="nofollow">Report Accessibility Concerns</a></p>
#  </div>
#  </div>,
#  <div class="block block-block first last odd" id="block-block-6">
#  <p style="text-align:center">© 2018 Regents of the University of Minnesota. All rights reserved. The University of Minnesota is an equal opportunity educator and employer.</p>
#  <p style="text-align:center"><a href="http://privacy.umn.edu/" rel="nofollow">Privacy Statement</a><br/><a href="http://oit-drupal-prd-web.oit.umn.edu/indexAccess.php?ref_url=https://twin-cities.umn.edu/content/home" rel="nofollow">Report Accessibility Concerns</a></p>
#  </div>]

# %%
from lxml import html
